# %% [markdown]
# <a href="https://colab.research.google.com/github/Niriksha77/Cointoss-Game/blob/main/Ai_Assistence_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
import google.generativeai as genai
from google.colab import userdata

# Fetch the API key from Colab secrets
api_key = userdata.get("GEMINI_API_KEY")

# Initialize the Gemini client
client = genai.configure(api_key=api_key)
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
def study_assistant(user_prompt):
  model = genai.GenerativeModel('gemini-2.5-flash')
  response = model.generate_content(user_prompt)
  return response.text

# %%
# Ask the study assistant a question
user_question = "What is a genAi?"
output = study_assistant(user_question)

# Print the result
print(output)
# Out:
# **GenAI** is short for **Generative Artificial Intelligence**.
#
# It's a type of artificial intelligence that can **create new and original content** across various formats, rather than just analyzing or classifying existing data.
#
# Here's a breakdown:
#
# 1.  **Artificial Intelligence (AI):** Broadly, AI refers to computer systems designed to perform tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and understanding language.
#
# 2.  **Generative:** This is the key differentiating factor. Unlike traditional AI that might identify a cat in an image or recommend a product, generative AI actually *produces* something new. It doesn't just retrieve information; it synthesizes it in novel ways.
#
# **How does GenAI work (in simple terms)?**
#
# ...
